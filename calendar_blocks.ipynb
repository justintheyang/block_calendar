# %%
from pieces import *
from puzzle_grid import *

# %%
all_pieces = {
    'A': PieceA(), 
    'B': PieceB(),
    'C': PieceC(),
    'D': PieceD(),
    'E': PieceE(),
    'F': PieceF(),
    'G': PieceG(),
    'H': PieceH(),
    'I': PieceI()
}
piece_id = {
    'A': 0, 
    'B': 1,
    'C': 2,
    'D': 3,
    'E': 4,
    'F': 5,
    'G': 6,
    'H': 7,
    'I': 8
}

# %%
all_pieces['A'].visualize_configurations()
all_pieces['B'].visualize_configurations()
all_pieces['C'].visualize_configurations()
all_pieces['D'].visualize_configurations()
all_pieces['E'].visualize_configurations()
all_pieces['F'].visualize_configurations()
all_pieces['G'].visualize_configurations()
all_pieces['H'].visualize_configurations()
all_pieces['I'].visualize_configurations()

# %%
# Example usage
grid = PuzzleGrid("May", "8")
grid.place_piece(all_pieces['A'], piece_id['A'], 3, 5)
grid.place_piece(all_pieces['D'].reflect(), piece_id['D'], 0, 4)
grid.place_piece(all_pieces['E'].rotate().rotate().rotate(), piece_id['E'], 4, 4)
grid.place_piece(all_pieces['B'], piece_id['B'], 2, 2)
grid.place_piece(all_pieces['C'], piece_id['C'], 1, 2)
grid.place_piece(all_pieces['F'].rotate().rotate(), piece_id['F'], 5, 2)
grid.place_piece(all_pieces['G'].rotate().rotate(), piece_id['G'], 4, 0)
grid.place_piece(all_pieces['H'].reflect().rotate(), piece_id['H'], 0, 1)
grid.place_piece(all_pieces['I'].rotate().rotate().rotate(), piece_id['I'], 0, 0)

grid.visualize_grid()
